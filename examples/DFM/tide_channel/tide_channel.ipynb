# %%
#------------------------------------------------------------------------------
# Import necessary modules
#------------------------------------------------------------------------------

from pathlib import Path
from dycove import VegetationSpecies, DFM_hydro

# %%
#------------------------------------------------------------------------------
# Define model file locations
#------------------------------------------------------------------------------

work_dir = Path.cwd()
config_file = work_dir / 'dimr_config.xml'
mdu_file    = work_dir / 'dflowfm/FlowFM.mdu'

DFM_DLLs = Path('C:/Program Files (x86)/Deltares/Delft3D Flexible Mesh Suite HM (2021.03)/'
                'plugins/DeltaShell.Dimr/kernels/x64')  # path to the local Delft3D software folder

# %%
#------------------------------------------------------------------------------
# Create vegetation species object
#------------------------------------------------------------------------------

veg_1 = VegetationSpecies(work_dir / "veg1.json")

# %%
#------------------------------------------------------------------------------
# Instantiate DFM model
#------------------------------------------------------------------------------

HydroModel = DFM_hydro.DFM(DFM_DLLs, config_file, mdu_file, vegetation=veg_1)

# %%
#------------------------------------------------------------------------------
# Do timestepping
#------------------------------------------------------------------------------

HydroModel.run_simulation(sim_time=1, sim_time_unit="eco-morphodynamic years")
# Out:
# 19:18:23 [WARNING] Morphology file NOT FOUND; proceeding with morphology off.
# 19:18:23 [INFO] Computed ecofac = 52, derived from veg_interval and n_ets (rounded from 52.143)
# 19:18:23 [INFO] ecofac = 52 corresponds to 364.00 days per year, OK.
# 19:18:23 [INFO] Running DYCOVE with 14 Eco Time Steps per year with coupling interval of 12 hours
# 19:18:23 [INFO] Hydrodynamic model duration: 7 days
# 19:18:23 [INFO] Eco-morphodynamic model duration: 1 years
# 19:18:23 [INFO] Current hydrodynamic model time = 0.0 days
# 19:18:23 [INFO] Current eco-morphodynamic model time = 0.0 years
# 19:18:23 [INFO] Current eco-morphodynamic model date = 2001-01-01 00:00:00
# 19:18:23 [INFO] Total time elapsed: 0.0 seconds
# 19:18:23 [INFO] Projected total run time based on average yield step: 0.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:26 [INFO] Doing colonization for species "veg1", at ETS 2
# 19:18:26 [INFO] Current hydrodynamic model time = 0.5 days
# 19:18:26 [INFO] Current eco-morphodynamic model time = 0.1 years
# 19:18:26 [INFO] Current eco-morphodynamic model date = 2001-01-27 00:00:00
# 19:18:26 [INFO] Total time elapsed: 3.0 seconds
# 19:18:26 [INFO] Projected total run time based on average yield step: 45.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:29 [INFO] Current hydrodynamic model time = 1.0 days
# 19:18:29 [INFO] Current eco-morphodynamic model time = 0.1 years
# 19:18:29 [INFO] Current eco-morphodynamic model date = 2001-02-22 00:00:00
# 19:18:29 [INFO] Total time elapsed: 6.0 seconds
# 19:18:29 [INFO] Projected total run time based on average yield step: 43.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:32 [INFO] Current hydrodynamic model time = 1.5 days
# 19:18:32 [INFO] Current eco-morphodynamic model time = 0.2 years
# 19:18:32 [INFO] Current eco-morphodynamic model date = 2001-03-20 00:00:00
# 19:18:32 [INFO] Total time elapsed: 9.0 seconds
# 19:18:32 [INFO] Projected total run time based on average yield step: 42.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:35 [INFO] Current hydrodynamic model time = 2.0 days
# 19:18:35 [INFO] Current eco-morphodynamic model time = 0.3 years
# 19:18:35 [INFO] Current eco-morphodynamic model date = 2001-04-15 00:00:00
# 19:18:35 [INFO] Total time elapsed: 12.0 seconds
# 19:18:35 [INFO] Projected total run time based on average yield step: 42.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:38 [INFO] Current hydrodynamic model time = 2.5 days
# 19:18:38 [INFO] Current eco-morphodynamic model time = 0.4 years
# 19:18:38 [INFO] Current eco-morphodynamic model date = 2001-05-11 00:00:00
# 19:18:38 [INFO] Total time elapsed: 15.0 seconds
# 19:18:38 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:40 [INFO] Current hydrodynamic model time = 3.0 days
# 19:18:40 [INFO] Current eco-morphodynamic model time = 0.4 years
# 19:18:40 [INFO] Current eco-morphodynamic model date = 2001-06-06 00:00:00
# 19:18:40 [INFO] Total time elapsed: 18.0 seconds
# 19:18:40 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:43 [INFO] Current hydrodynamic model time = 3.5 days
# 19:18:43 [INFO] Current eco-morphodynamic model time = 0.5 years
# 19:18:43 [INFO] Current eco-morphodynamic model date = 2001-07-02 00:00:00
# 19:18:43 [INFO] Total time elapsed: 20.0 seconds
# 19:18:43 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:46 [INFO] Current hydrodynamic model time = 4.0 days
# 19:18:46 [INFO] Current eco-morphodynamic model time = 0.6 years
# 19:18:46 [INFO] Current eco-morphodynamic model date = 2001-07-28 00:00:00
# 19:18:46 [INFO] Total time elapsed: 23.0 seconds
# 19:18:46 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:49 [INFO] Current hydrodynamic model time = 4.5 days
# 19:18:49 [INFO] Current eco-morphodynamic model time = 0.6 years
# 19:18:49 [INFO] Current eco-morphodynamic model date = 2001-08-23 00:00:00
# 19:18:49 [INFO] Total time elapsed: 26.0 seconds
# 19:18:49 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:52 [INFO] Current hydrodynamic model time = 5.0 days
# 19:18:52 [INFO] Current eco-morphodynamic model time = 0.7 years
# 19:18:52 [INFO] Current eco-morphodynamic model date = 2001-09-18 00:00:00
# 19:18:52 [INFO] Total time elapsed: 29.0 seconds
# 19:18:52 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:55 [INFO] Current hydrodynamic model time = 5.5 days
# 19:18:55 [INFO] Current eco-morphodynamic model time = 0.8 years
# 19:18:55 [INFO] Current eco-morphodynamic model date = 2001-10-14 00:00:00
# 19:18:55 [INFO] Total time elapsed: 32.0 seconds
# 19:18:55 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:18:58 [INFO] Current hydrodynamic model time = 6.0 days
# 19:18:58 [INFO] Current eco-morphodynamic model time = 0.9 years
# 19:18:58 [INFO] Current eco-morphodynamic model date = 2001-11-09 00:00:00
# 19:18:58 [INFO] Total time elapsed: 35.0 seconds
# 19:18:58 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:19:01 [INFO] Current hydrodynamic model time = 6.5 days
# 19:19:01 [INFO] Current eco-morphodynamic model time = 0.9 years
# 19:19:01 [INFO] Current eco-morphodynamic model date = 2001-12-05 00:00:00
# 19:19:01 [INFO] Total time elapsed: 38.0 seconds
# 19:19:01 [INFO] Projected total run time based on average yield step: 41.0 seconds
#
# ##### --------------------------------------------- #####
#
# 19:19:04 [INFO] Merging outputs, cleaning up, and finalizing simulation...
# 19:19:04 [INFO] Simulation complete!
